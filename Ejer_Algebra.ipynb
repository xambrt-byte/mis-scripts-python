# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from fractions import Fraction

f1= Fraction(7,6)
f2= Fraction(-4,8)
f3= Fraction(5,8)
f4= Fraction(-4,3)
print(f1/f2 - f3*f4)
print((7/6)*(-4/8)-(5/8)*(-4/3))
# Out:
# -3/2
# 0.2499999999999999

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, simplify, powdenest
from fractions import Fraction

x, y = symbols('x y')   # Declaracion de variables
expr = (3*x**(-2)*y**3)**3 * (-2*x**4*y**(-8))**2 - (16*x**4*y**(-2))**2 / (4*x**6*y**3)
simplify(expr)
# Out:
# 44*x**2/y**7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, simplify, powdenest
from fractions import Fraction

x, y = symbols('x y')
expr = ( (4096*x**8*y**9)**Fraction(1,2) / (512*x**(-3)*y**12)**Fraction(1,3) )**Fraction(1,3)
#simplify(expr
powdenest(expr, force=True)
# Out:
# 2*x**(5/3)*y**(1/6)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, solveset
x, y =symbols('x y')

expr = 3*x**2 + x + 1 - (3*x**3 - 2) / x + x + 4
solveset(expr)
# Out:
# {-2, -1/2}

# %% [markdown]
# ![image.png](data:image/png;base64,...)
